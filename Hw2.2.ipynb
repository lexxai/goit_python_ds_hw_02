# %% [markdown]
# <a href="https://colab.research.google.com/github/lexxai/goit_python_ds_hw_02/blob/main/Hw2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Частина друга: Аналіз файлів
# ## Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %% [markdown]
# # Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.12)
# time: 387 µs (started: 2024-01-06 17:09:44 +00:00)

# %%
import pandas as pd

URL="https://drive.usercontent.google.com/download?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U&export=download&authuser=0"
df = pd.read_csv(URL)
assert df is not None, "DATA NOT READ FROM THE URL"
# Out:
# time: 1.59 s (started: 2024-01-06 17:09:44 +00:00)

# %% [markdown]
# # Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head(3)
# Out:
#    N           Должность Язык.программирования Специализация  \
# 0  1  Junior QA engineer                   NaN     Manual QA
# 1  2  Junior QA engineer                   NaN     Manual QA
# 2  3   Software Engineer               C#/.NET           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#    exp current_job_exp salary Валюта  cls
# 0  0.5             0.5    400    NaN   QA
# 1  0.0             0.0    430    NaN   QA
# 2  4.0             1.0   2500    NaN  DEV
#
# [3 rows x 25 columns]
# time: 25.3 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Визначте розмір таблиці за допомогою методу shape

# %%
print(df.shape)
# Out:
# (8704, 25)
# time: 903 µs (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
print(df[df.columns].dtypes)
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object
# time: 9.34 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64
# time: 29.6 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
cols = df.isnull().sum() > 0
cols["Язык.программирования"]=False
print(cols)
cols1 = cols[cols==False].index
print(cols1)
df=df[cols1]
df.head()
# Out:
# N                                   False
# Должность                           False
# Язык.программирования               False
# Общий.опыт.работы                   False
# Опыт.работы.на.текущем.месте        False
# Зарплата.в.месяц                    False
# Изменение.зарплаты.за.12.месяцев    False
# Город                               False
# Размер.компании                     False
# Тип.компании                        False
# Пол                                 False
# Возраст                             False
# Образование                         False
# Еще.студент                         False
# Уровень.английского                 False
# Дата.заполнения                     False
# User.Agent                          False
# exp                                 False
# current_job_exp                     False
# salary                              False
# dtype: bool
# Index(['N', 'Должность', 'Язык.программирования', 'Общий.опыт.работы',
#        'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц',
#        'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании',
#        'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Еще.студент',
#        'Уровень.английского', 'Дата.заполнения', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
# 6  7  Junior Software Engineer               C#/.NET                 1
# 7  8  Senior Software Engineer                   C++                 6
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
# 6             меньше 3 месяцев               600
# 7                            1              3300
#
#    Изменение.зарплаты.за.12.месяцев        Город  Размер.компании  \
# 2                               800         Киев  до 1000 человек
# 3                               400       Одесса   до 200 человек
# 4                               500       Другой    до 10 человек
# 6                               100  Хмельницкий    до 50 человек
# 7                               500         Киев    до 10 человек
#
#      Тип.компании      Пол  Возраст         Образование  Еще.студент  \
# 2  Аутсорсинговая  мужской       26              Высшее        False
# 3     Продуктовая  мужской       30             Среднее        False
# 4     Продуктовая  мужской       30  Техникум / Колледж        False
# 6  Аутсорсинговая  мужской       23              Высшее        False
# 7     Продуктовая  мужской       28              Высшее        False
#
#   Уровень.английского      Дата.заполнения  \
# 2             средний  12/06/2017 13:02:47
# 3       ниже среднего  12/06/2017 13:03:01
# 4             средний  12/06/2017 13:03:47
# 6       ниже среднего  12/06/2017 13:04:26
# 7       выше среднего  12/06/2017 13:04:27
#
#                                           User.Agent   exp  current_job_exp  \
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0              1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0              4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0              0.5
# 6  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.0              0.0
# 7  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   6.0              1.0
#
#    salary
# 2    2500
# 3    2000
# 4    4500
# 6     600
# 7    3300
# time: 36.8 ms (started: 2024-01-06 17:13:46 +00:00)

# %% [markdown]
# # Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64
# time: 27.7 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# N                                   0
# Должность                           0
# Язык.программирования               0
# Общий.опыт.работы                   0
# Опыт.работы.на.текущем.месте        0
# Зарплата.в.месяц                    0
# Изменение.зарплаты.за.12.месяцев    0
# Город                               0
# Размер.компании                     0
# Тип.компании                        0
# Пол                                 0
# Возраст                             0
# Образование                         0
# Еще.студент                         0
# Уровень.английского                 0
# Дата.заполнения                     0
# User.Agent                          0
# exp                                 0
# current_job_exp                     0
# salary                              0
# dtype: int64
# time: 48.4 ms (started: 2024-01-06 17:14:26 +00:00)

# %% [markdown]
# # Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)
# time: 3 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Язык.программирования'].str.lower() == "python"]
# Out:
# time: 7.37 ms (started: 2024-01-06 17:14:53 +00:00)

# %% [markdown]
# # Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)
# time: 3.13 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
gr_by_posada = python_data.groupby(['Должность'])
# Out:
# time: 1.02 ms (started: 2024-01-06 17:15:29 +00:00)

# %%
gr_by_posada.count().index
# Out:
# Index(['Junior Software Engineer', 'Senior Software Engineer',
#        'Software Engineer', 'System Architect', 'Technical Lead'],
#       dtype='object', name='Должность')
# time: 7.23 ms (started: 2024-01-06 17:15:32 +00:00)

# %%
gr_by_posada.mean(numeric_only=True).sort_values("salary", ascending=False)
# Out:
#                                     N  Зарплата.в.месяц  \
# Должность
# System Architect          6989.000000       4000.000000
# Senior Software Engineer  4781.870968       3387.096774
# Technical Lead            5370.181818       3165.909091
# Software Engineer         3668.840000       1799.070000
# Junior Software Engineer  3559.063492        560.841270
#
#                           Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# System Architect                                  0.000000  35.500000
# Senior Software Engineer                        431.612903  29.064516
# Technical Lead                                  455.000000  30.090909
# Software Engineer                               479.830000  26.630000
# Junior Software Engineer                        181.031746  24.174603
#
#                           Еще.студент        exp  current_job_exp       salary
# Должность
# System Architect             0.000000  10.000000         1.125000  4000.000000
# Senior Software Engineer     0.032258   6.677419         1.556452  3387.096774
# Technical Lead               0.000000   7.090909         3.386364  3165.909091
# Software Engineer            0.130000   3.180000         1.127500  1799.070000
# Junior Software Engineer     0.380952   0.876984         0.523810   560.841270
# time: 22.2 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
gr_by_posada['salary'] \
  .agg(['min', 'mean', 'max'])\
  .sort_values("mean", ascending=False) \
  .apply(lambda x: pd.to_numeric(x, errors='coerce').astype(int) )
# Out:
#                            min  mean   max
# Должность
# System Architect          3000  4000  5000
# Senior Software Engineer  1300  3387  9200
# Technical Lead            1425  3165  6200
# Software Engineer          500  1799  5400
# Junior Software Engineer   100   560  1250
# time: 14 ms (started: 2024-01-06 17:09:46 +00:00)

# %%
spec_stat = gr_by_posada['salary'].agg(['min', 'max'])
spec_stat.head()
# Out:
#                            min   max
# Должность
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200
# time: 8.37 ms (started: 2024-01-06 17:09:46 +00:00)

# %% [markdown]
# # Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
gr_by_posada['salary'].mean(numeric_only=True)
# Out:
# Должность
# Junior Software Engineer     560.841270
# Senior Software Engineer    3387.096774
# Software Engineer           1799.070000
# System Architect            4000.000000
# Technical Lead              3165.909091
# Name: salary, dtype: float64
# time: 4.91 ms (started: 2024-01-06 17:09:46 +00:00)

# %%
gr_by_posada['salary'].agg('mean')
# Out:
# Должность
# Junior Software Engineer     560.841270
# Senior Software Engineer    3387.096774
# Software Engineer           1799.070000
# System Architect            4000.000000
# Technical Lead              3165.909091
# Name: salary, dtype: float64
# time: 8.17 ms (started: 2024-01-06 17:09:46 +00:00)

# %%
spec_stat = gr_by_posada['salary'].agg(['min', 'max'])
print(spec_stat)
gr_by_posada['salary'].describe()
# Out:
#                            min   max
# Должность
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200
#                           count         mean          std     min     25%  \
# Должность
# Junior Software Engineer   63.0   560.841270   266.199974   100.0   400.0
# Senior Software Engineer   31.0  3387.096774  1402.317590  1300.0  2800.0
# Software Engineer         100.0  1799.070000   845.746174   500.0  1200.0
# System Architect            2.0  4000.000000  1414.213562  3000.0  3500.0
# Technical Lead             11.0  3165.909091  1236.844409  1425.0  2600.0
#
#                              50%     75%     max
# Должность
# Junior Software Engineer   500.0   775.0  1250.0
# Senior Software Engineer  3200.0  3750.0  9200.0
# Software Engineer         1725.0  2125.0  5400.0
# System Architect          4000.0  4500.0  5000.0
# Technical Lead            3000.0  3600.0  6200.0
# time: 41.1 ms (started: 2024-01-06 17:09:46 +00:00)

# %%
# USE REFERENCE

def fill_avg_salary(s, ref_df):
  avg = None
  try:
    sp = s.get('Должность')
    if sp:
      stat_sp = ref_df.loc[sp]
      avg=int((stat_sp["min"] + stat_sp["max"])/2)
  finally:
    s['avg']=avg
    return s


a=df.apply(fill_avg_salary, args=[spec_stat], axis=1)
a[a.columns[[0,1,2,19,20]]].head(2)
# Out:
#    N          Должность Язык.программирования  salary     avg
# 2  3  Software Engineer               C#/.NET    2500  2950.0
# 3  4  Software Engineer            JavaScript    2000  2950.0
# time: 3.7 s (started: 2024-01-06 17:09:46 +00:00)

# %%
# USE GLOBAL ENV

def fill_avg_salary(s):
  avg = None
  try:
    sp = s.get('Должность')
    if sp:
      stat_sp = spec_stat.loc[sp]
      avg=int((stat_sp["min"] + stat_sp["max"])/2)
  finally:
    s['avg']=avg
    return s


a=df.apply(fill_avg_salary, axis=1)
a[a.columns[[0,1,2,19,20]]].head(2)
# Out:
#    N          Должность Язык.программирования  salary     avg
# 2  3  Software Engineer               C#/.NET    2500  2950.0
# 3  4  Software Engineer            JavaScript    2000  2950.0
# time: 3.61 s (started: 2024-01-06 17:09:50 +00:00)

# %%
def fill_avg(s):
  avg = None
  try:
      avg=int((s["min"] + s["max"])/2)
  finally:
    s['avg']=avg
    return s

b=spec_stat.apply(fill_avg, axis=1)
b
# Out:
#                            min   max   avg
# Должность
# Junior Software Engineer   100  1250   675
# Senior Software Engineer  1300  9200  5250
# Software Engineer          500  5400  2950
# System Architect          3000  5000  4000
# Technical Lead            1425  6200  3812
# time: 12.8 ms (started: 2024-01-06 17:09:54 +00:00)

# %% [markdown]
# # Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
gr_by_posada['salary'] \
  .agg(['mean']).describe()
# Out:
#               mean
# count     5.000000
# mean   2582.583427
# std    1387.255829
# min     560.841270
# 25%    1799.070000
# 50%    3165.909091
# 75%    3387.096774
# max    4000.000000
# time: 12.2 ms (started: 2024-01-06 17:09:54 +00:00)

# %%
a['avg'].describe()
# Out:
# count    4843.000000
# mean     2920.214743
# std      1612.574951
# min       675.000000
# 25%       675.000000
# 50%      2950.000000
# 75%      3812.000000
# max      5250.000000
# Name: avg, dtype: float64
# time: 9.49 ms (started: 2024-01-06 17:09:54 +00:00)

# %%
b['avg'].describe()
# Out:
# count       5.000000
# mean     3337.400000
# std      1700.056999
# min       675.000000
# 25%      2950.000000
# 50%      3812.000000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64
# time: 6.88 ms (started: 2024-01-06 17:09:54 +00:00)

# %% [markdown]
# # Збережіть отриману таблицю в CSV файл

# %%
a.to_csv("Hw2.2a.csv")
# Out:
# time: 80.8 ms (started: 2024-01-06 17:09:54 +00:00)

# %%
b.to_csv("Hw2.2b.csv")
# Out:
# time: 2 ms (started: 2024-01-06 17:09:54 +00:00)
