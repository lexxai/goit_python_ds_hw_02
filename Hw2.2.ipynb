# %% [markdown]
# <a href="https://colab.research.google.com/github/lexxai/goit_python_ds_hw_02/blob/main/Hw2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Частина друга: Аналіз файлів
# ## Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %% [markdown]
# # Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.12)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.1
# time: 326 µs (started: 2024-01-06 14:34:09 +00:00)

# %%
import pandas as pd

URL="https://drive.usercontent.google.com/download?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U&export=download&authuser=0"
df = pd.read_csv(URL)
assert df is not None, "DATA NOT READ FROM THE URL"
# Out:
# time: 1.48 s (started: 2024-01-06 14:34:09 +00:00)

# %% [markdown]
# # Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head(3)
# Out:
#    N           Должность Язык.программирования Специализация  \
# 0  1  Junior QA engineer                   NaN     Manual QA
# 1  2  Junior QA engineer                   NaN     Manual QA
# 2  3   Software Engineer               C#/.NET           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#    exp current_job_exp salary Валюта  cls
# 0  0.5             0.5    400    NaN   QA
# 1  0.0             0.0    430    NaN   QA
# 2  4.0             1.0   2500    NaN  DEV
#
# [3 rows x 25 columns]
# time: 27.3 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Визначте розмір таблиці за допомогою методу shape

# %%
print(df.shape)
# Out:
# (8704, 25)
# time: 1.42 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
print(df[df.columns].dtypes)
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object
# time: 6.13 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64
# time: 35.6 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
cols = df.isnull().sum() > 0
cols["Язык.программирования"]=False
print(cols)
cols1 = cols[cols==False].index
print(cols1)
df=df[cols1]
df.head()
# Out:
# N                                   False
# Должность                           False
# Язык.программирования               False
# Специализация                        True
# Общий.опыт.работы                   False
# Опыт.работы.на.текущем.месте        False
# Зарплата.в.месяц                    False
# Изменение.зарплаты.за.12.месяцев    False
# Город                               False
# Размер.компании                     False
# Тип.компании                        False
# Пол                                 False
# Возраст                             False
# Образование                         False
# Университет                          True
# Еще.студент                         False
# Уровень.английского                 False
# Предметная.область                   True
# Дата.заполнения                     False
# User.Agent                          False
# exp                                 False
# current_job_exp                     False
# salary                              False
# Валюта                               True
# cls                                  True
# dtype: bool
# Index(['N', 'Должность', 'Язык.программирования', 'Общий.опыт.работы',
#        'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц',
#        'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании',
#        'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Еще.студент',
#        'Уровень.английского', 'Дата.заполнения', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 0  1        Junior QA engineer                   NaN               0.5
# 1  2        Junior QA engineer                   NaN  меньше 3 месяцев
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                          0.5               400
# 1             меньше 3 месяцев               430
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                 0  Харьков       до 10 человек
# 1                               130  Харьков  свыше 1000 человек
# 2                               800     Киев     до 1000 человек
# 3                               400   Одесса      до 200 человек
# 4                               500   Другой       до 10 человек
#
#      Тип.компании      Пол  Возраст           Образование  Еще.студент  \
# 0  Аутсорсинговая  женский       20  Незаконченное высшее         True
# 1  Аутсорсинговая  женский       21  Незаконченное высшее         True
# 2  Аутсорсинговая  мужской       26                Высшее        False
# 3     Продуктовая  мужской       30               Среднее        False
# 4     Продуктовая  мужской       30    Техникум / Колледж        False
#
#   Уровень.английского      Дата.заполнения  \
# 0       ниже среднего  12/06/2017 12:38:08
# 1       выше среднего  12/06/2017 12:42:51
# 2             средний  12/06/2017 13:02:47
# 3       ниже среднего  12/06/2017 13:03:01
# 4             средний  12/06/2017 13:03:47
#
#                                           User.Agent   exp  current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5              0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0              0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0              1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0              4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0              0.5
#
#    salary
# 0     400
# 1     430
# 2    2500
# 3    2000
# 4    4500
# time: 46 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64
# time: 25 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# <ipython-input-9-ade90e9e5014>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# N                                   0
# Должность                           0
# Язык.программирования               0
# Общий.опыт.работы                   0
# Опыт.работы.на.текущем.месте        0
# Зарплата.в.месяц                    0
# Изменение.зарплаты.за.12.месяцев    0
# Город                               0
# Размер.компании                     0
# Тип.компании                        0
# Пол                                 0
# Возраст                             0
# Образование                         0
# Еще.студент                         0
# Уровень.английского                 0
# Дата.заполнения                     0
# User.Agent                          0
# exp                                 0
# current_job_exp                     0
# salary                              0
# dtype: int64
# time: 36.9 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)
# time: 5.57 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Язык.программирования'].str.lower() == "python"]
# Out:
# time: 3.77 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)
# time: 3.8 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
python_data.groupby(['Должность']).mean(numeric_only=True).sort_values("salary", ascending=False)
# Out:
#                                     N  Зарплата.в.месяц  \
# Должность
# System Architect          6989.000000       4000.000000
# Senior Software Engineer  4781.870968       3387.096774
# Technical Lead            5370.181818       3165.909091
# Software Engineer         3668.840000       1799.070000
# Junior Software Engineer  3559.063492        560.841270
#
#                           Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# System Architect                                  0.000000  35.500000
# Senior Software Engineer                        431.612903  29.064516
# Technical Lead                                  455.000000  30.090909
# Software Engineer                               479.830000  26.630000
# Junior Software Engineer                        181.031746  24.174603
#
#                           Еще.студент        exp  current_job_exp       salary
# Должность
# System Architect             0.000000  10.000000         1.125000  4000.000000
# Senior Software Engineer     0.032258   6.677419         1.556452  3387.096774
# Technical Lead               0.000000   7.090909         3.386364  3165.909091
# Software Engineer            0.130000   3.180000         1.127500  1799.070000
# Junior Software Engineer     0.380952   0.876984         0.523810   560.841270
# time: 29 ms (started: 2024-01-06 14:34:11 +00:00)

# %%
df.groupby(['Должность']).mean(numeric_only=True).sort_values("salary", ascending=False)
# Out:
#                                          N  Зарплата.в.месяц  \
# Должность
# DevOps                         2912.000000       7000.000000
# System Architect               4594.584615       4387.076923
# Technical Lead                 4693.468000       3664.272000
# Team lead                      6055.500000       3250.000000
# Senior Software Engineer       4093.471296       3243.200926
# Product Manager                4099.000000       3000.000000
# Data Scientist / Data Analyst  1707.000000       2700.000000
# ERP / CRM                      6713.000000       2000.000000
# Software Engineer              4187.184041       1678.630074
# Junior Software Engineer       4410.929688        605.658594
# HTML coder                     3741.200000        457.000000
#
#                                Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# DevOps                                              5500.000000  29.000000
# System Architect                                     436.923077  31.123077
# Technical Lead                                       433.508000  30.972000
# Team lead                                            500.000000  27.000000
# Senior Software Engineer                             428.262037  30.079630
# Product Manager                                      500.000000  35.000000
# Data Scientist / Data Analyst                        300.000000  35.000000
# ERP / CRM                                           1000.000000  29.000000
# Software Engineer                                    448.833026  26.932196
# Junior Software Engineer                             214.321094  24.192187
# HTML coder                                            70.000000  27.200000
#
#                                Еще.студент       exp  current_job_exp  \
# Должность
# DevOps                            0.000000  8.000000         0.000000
# System Architect                  0.046154  8.234615         4.053846
# Technical Lead                    0.024000  7.818000         3.249000
# Team lead                         0.000000  6.000000         4.500000
# Senior Software Engineer          0.019444  6.776620         2.425231
# Product Manager                   0.000000  7.000000         7.000000
# Data Scientist / Data Analyst     0.000000  1.500000         0.000000
# ERP / CRM                         1.000000  2.000000         1.000000
# Software Engineer                 0.101937  3.444073         1.520065
# Junior Software Engineer          0.343750  1.059180         0.663086
# HTML coder                        0.000000  1.700000         0.500000
#
#                                     salary
# Должность
# DevOps                         7000.000000
# System Architect               4387.076923
# Technical Lead                 3664.272000
# Team lead                      3250.000000
# Senior Software Engineer       3243.200926
# Product Manager                3000.000000
# Data Scientist / Data Analyst  2700.000000
# ERP / CRM                      2000.000000
# Software Engineer              1678.630074
# Junior Software Engineer        605.658594
# HTML coder                      457.000000
# time: 27 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
df.groupby(['Должность'])['salary'] \
  .agg(['min', 'mean', 'max'])\
  .sort_values("mean", ascending=False) \
  .apply(lambda x: pd.to_numeric(x, errors='coerce').astype(int) )
# Out:
#                                 min  mean    max
# Должность
# DevOps                         7000  7000   7000
# System Architect                400  4387  10000
# Technical Lead                  500  3664  18000
# Team lead                      2500  3250   4000
# Senior Software Engineer        350  3243   9200
# Product Manager                3000  3000   3000
# Data Scientist / Data Analyst  2700  2700   2700
# ERP / CRM                      2000  2000   2000
# Software Engineer               100  1678   7000
# Junior Software Engineer         75   605   2600
# HTML coder                      385   457    600
# time: 33.6 ms (started: 2024-01-06 14:34:11 +00:00)

# %%
spec_stat = df.groupby(['Должность'])['salary'] \
  .agg(['min', 'max'])
spec_stat.head()
# Out:
#                                 min   max
# Должность
# Data Scientist / Data Analyst  2700  2700
# DevOps                         7000  7000
# ERP / CRM                      2000  2000
# HTML coder                      385   600
# Junior Software Engineer         75  2600
# time: 18.7 ms (started: 2024-01-06 14:34:11 +00:00)

# %% [markdown]
# # Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
df.groupby(['Должность']).mean(numeric_only=True)
# Out:
#                                          N  Зарплата.в.месяц  \
# Должность
# Data Scientist / Data Analyst  1707.000000       2700.000000
# DevOps                         2912.000000       7000.000000
# ERP / CRM                      6713.000000       2000.000000
# HTML coder                     3741.200000        457.000000
# Junior Software Engineer       4410.929688        605.658594
# Product Manager                4099.000000       3000.000000
# Senior Software Engineer       4093.471296       3243.200926
# Software Engineer              4187.184041       1678.630074
# System Architect               4594.584615       4387.076923
# Team lead                      6055.500000       3250.000000
# Technical Lead                 4693.468000       3664.272000
#
#                                Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# Data Scientist / Data Analyst                        300.000000  35.000000
# DevOps                                              5500.000000  29.000000
# ERP / CRM                                           1000.000000  29.000000
# HTML coder                                            70.000000  27.200000
# Junior Software Engineer                             214.321094  24.192187
# Product Manager                                      500.000000  35.000000
# Senior Software Engineer                             428.262037  30.079630
# Software Engineer                                    448.833026  26.932196
# System Architect                                     436.923077  31.123077
# Team lead                                            500.000000  27.000000
# Technical Lead                                       433.508000  30.972000
#
#                                Еще.студент       exp  current_job_exp  \
# Должность
# Data Scientist / Data Analyst     0.000000  1.500000         0.000000
# DevOps                            0.000000  8.000000         0.000000
# ERP / CRM                         1.000000  2.000000         1.000000
# HTML coder                        0.000000  1.700000         0.500000
# Junior Software Engineer          0.343750  1.059180         0.663086
# Product Manager                   0.000000  7.000000         7.000000
# Senior Software Engineer          0.019444  6.776620         2.425231
# Software Engineer                 0.101937  3.444073         1.520065
# System Architect                  0.046154  8.234615         4.053846
# Team lead                         0.000000  6.000000         4.500000
# Technical Lead                    0.024000  7.818000         3.249000
#
#                                     salary
# Должность
# Data Scientist / Data Analyst  2700.000000
# DevOps                         7000.000000
# ERP / CRM                      2000.000000
# HTML coder                      457.000000
# Junior Software Engineer        605.658594
# Product Manager                3000.000000
# Senior Software Engineer       3243.200926
# Software Engineer              1678.630074
# System Architect               4387.076923
# Team lead                      3250.000000
# Technical Lead                 3664.272000
# time: 31 ms (started: 2024-01-06 14:34:11 +00:00)

# %%
df['salary'].mean()
# Out:
# 1883.371034198599
# time: 6.3 ms (started: 2024-01-06 14:34:11 +00:00)

# %%
df.groupby(['Должность'])['salary'] \
  .agg(['mean'])
# Out:
#                                       mean
# Должность
# Data Scientist / Data Analyst  2700.000000
# DevOps                         7000.000000
# ERP / CRM                      2000.000000
# HTML coder                      457.000000
# Junior Software Engineer        605.658594
# Product Manager                3000.000000
# Senior Software Engineer       3243.200926
# Software Engineer              1678.630074
# System Architect               4387.076923
# Team lead                      3250.000000
# Technical Lead                 3664.272000
# time: 12.5 ms (started: 2024-01-06 16:16:57 +00:00)

# %%
spec_stat = df.groupby(['Должность'])['salary'].agg(['min', 'max'])
print(spec_stat)
df.groupby(['Должность'])['salary'].describe()
# Out:
#                                 min    max
# Должность
# Data Scientist / Data Analyst  2700   2700
# DevOps                         7000   7000
# ERP / CRM                      2000   2000
# HTML coder                      385    600
# Junior Software Engineer         75   2600
# Product Manager                3000   3000
# Senior Software Engineer        350   9200
# Software Engineer               100   7000
# System Architect                400  10000
# Team lead                      2500   4000
# Technical Lead                  500  18000
#                                 count         mean          std     min  \
# Должность
# Data Scientist / Data Analyst     1.0  2700.000000          NaN  2700.0
# DevOps                            1.0  7000.000000          NaN  7000.0
# ERP / CRM                         1.0  2000.000000          NaN  2000.0
# HTML coder                        5.0   457.000000    92.168324   385.0
# Junior Software Engineer       1280.0   605.658594   314.533053    75.0
# Product Manager                   1.0  3000.000000          NaN  3000.0
# Senior Software Engineer       1080.0  3243.200926  1065.735960   350.0
# Software Engineer              2168.0  1678.630074   743.617391   100.0
# System Architect                 65.0  4387.076923  1771.276661   400.0
# Team lead                         2.0  3250.000000  1060.660172  2500.0
# Technical Lead                  250.0  3664.272000  1421.826694   500.0
#
#                                   25%     50%      75%      max
# Должность
# Data Scientist / Data Analyst  2700.0  2700.0  2700.00   2700.0
# DevOps                         7000.0  7000.0  7000.00   7000.0
# ERP / CRM                      2000.0  2000.0  2000.00   2000.0
# HTML coder                      400.0   400.0   500.00    600.0
# Junior Software Engineer        400.0   550.0   792.50   2600.0
# Product Manager                3000.0  3000.0  3000.00   3000.0
# Senior Software Engineer       2550.0  3200.0  3750.00   9200.0
# Software Engineer              1100.0  1600.0  2188.75   7000.0
# System Architect               3600.0  4300.0  5000.00  10000.0
# Team lead                      2875.0  3250.0  3625.00   4000.0
# Technical Lead                 3000.0  3675.0  4300.00  18000.0
# time: 46.7 ms (started: 2024-01-06 16:22:42 +00:00)

# %%
# USE REFERENCE

def fill_avg_salary(s, ref_df):
  avg = None
  try:
    sp = s.get('Должность')
    if sp:
      stat_sp = ref_df.loc[sp]
      avg=int((stat_sp["min"] + stat_sp["max"])/2)
  finally:
    s['avg']=avg
    return s


a=df.apply(fill_avg_salary, args=[spec_stat], axis=1)
a[a.columns[[0,1,2,19,20]]].head(2)
# Out:
#    N          Должность Язык.программирования  salary   avg
# 2  3  Software Engineer               C#/.NET    2500  3550
# 3  4  Software Engineer            JavaScript    2000  3550
# time: 3.96 s (started: 2024-01-06 14:34:11 +00:00)

# %%
# USE GLOBAL ENV

def fill_avg_salary(s):
  avg = None
  try:
    sp = s.get('Должность')
    if sp:
      stat_sp = spec_stat.loc[sp]
      avg=int((stat_sp["min"] + stat_sp["max"])/2)
  finally:
    s['avg']=avg
    return s


a=df.apply(fill_avg_salary, axis=1)
a[a.columns[[0,1,2,19,20]]].head(2)
# Out:
#    N          Должность Язык.программирования  salary   avg
# 2  3  Software Engineer               C#/.NET    2500  3550
# 3  4  Software Engineer            JavaScript    2000  3550
# time: 7.85 s (started: 2024-01-06 14:34:15 +00:00)

# %% [markdown]
# # Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
df.groupby(['Должность'])['salary'] \
  .agg(['mean']).describe()
# Out:
#               mean
# count    11.000000
# mean   2907.803502
# std    1828.363270
# min     457.000000
# 25%    1839.315037
# 50%    3000.000000
# 75%    3457.136000
# max    7000.000000
# time: 13.3 ms (started: 2024-01-06 16:19:44 +00:00)

# %%
a['avg'].describe()
# Out:
# count    4854.000000
# mean     3551.487433
# std      1829.933238
# min       492.000000
# 25%      1337.000000
# 50%      3550.000000
# 75%      4775.000000
# max      9250.000000
# Name: avg, dtype: float64
# time: 11.7 ms (started: 2024-01-06 16:15:41 +00:00)

# %% [markdown]
# # Збережіть отриману таблицю в CSV файл

# %%
a.to_csv("Hw2.2.csv")
# Out:
# time: 131 ms (started: 2024-01-06 14:34:23 +00:00)
